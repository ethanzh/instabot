# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("scrape_data.csv")

# %%
pd.to_numeric(data["following"])
# Out:
# 0         94
# 1      17400
# 2        337
# 3        807
# 4        525
# 5        607
# 6        257
# 7        174
# 8        829
# 9         55
# 10     29800
# 11      1396
# 12      1048
# 13       147
# 14        22
# 15        52
# 16       670
# 17       329
# 18       109
# 19      6238
# 20      3563
# 21      1166
# 22       338
# 23     30600
# 24      1326
# 25       307
# 26       225
# 27        33
# 28     10400
# 29      1117
#        ...
# 383      346
# 384      110
# 385      324
# 386      250
# 387       55
# 388        6
# 389      111
# 390      406
# 391     1390
# 392     5253
# 393      765
# 394       29
# 395      830
# 396      673
# 397     1392
# 398     7627
# 399     1439
# 400     1485
# 401      176
# 402       27
# 403      288
# 404      256
# 405      229
# 406     1245
# 407      243
# 408        3
# 409      262
# 410      478
# 411       17
# 412     2175
# Name: following, Length: 413, dtype: int64

# %%
x = data["followers"]# / data["following"]
y = data["following"]

# %%
plt.scatter(x, y, alpha=0.5)
plt.xlim(0, 3000)
plt.ylim(0, 2000)
plt.show()
